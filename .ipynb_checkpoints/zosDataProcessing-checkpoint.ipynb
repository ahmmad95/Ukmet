# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
plt.rcParams["figure.figsize"] = (8,5)
import warnings
warnings.filterwarnings('ignore')

# %%
Data=pd.read_excel(r'E:\MYS\Extracted Data\zos\Location5.xlsx')
Data=Data[Data['Sea Surface Height Above Geoid (m)']!=1.000000020040877e+20].reset_index(drop=True)
Data['date']=Data['date'].apply(lambda x: datetime.strptime(str(x), '%Y-%m-%d %H:%M:%S'))
Data=Data[Data['date']<=datetime(2100, 12, 31)].reset_index(drop=True)

# %%
df=Data[Data['projection']=='rcp45']
df.reset_index(drop=True,inplace=True)
#df['dff']=df.groupby(['model','projection','ensemble'])['Sea Surface Height Above Geoid (m)'].diff()
#df.dropna(inplace=True)
#df.reset_index(drop=True,inplace=True)
#df.set_index('date',inplace=True)

# %%
for df1, df_g in df.groupby(['model','projection','ensemble']):
    index=df_g.index
    idxmin=min(index)
    df.loc[index,'change']=df.loc[index,'Sea Surface Height Above Geoid (m)']-df.loc[idxmin,'Sea Surface Height Above Geoid (m)']
    #print(min(index))

# %%
df
# Out:
#             model projection ensemble                 date  \
# 0       ACCESS1-0      rcp45   r1i1p1  2006-01-16 12:00:00
# 1       ACCESS1-0      rcp45   r1i1p1  2006-02-15 00:00:00
# 2       ACCESS1-0      rcp45   r1i1p1  2006-03-16 12:00:00
# 3       ACCESS1-0      rcp45   r1i1p1  2006-04-16 00:00:00
# 4       ACCESS1-0      rcp45   r1i1p1  2006-05-16 12:00:00
# ...           ...        ...      ...                  ...
# 61848  NorESM1-ME      rcp45   r1i1p1  2100-08-16 12:00:00
# 61849  NorESM1-ME      rcp45   r1i1p1  2100-09-16 00:00:00
# 61850  NorESM1-ME      rcp45   r1i1p1  2100-10-16 12:00:00
# 61851  NorESM1-ME      rcp45   r1i1p1  2100-11-16 00:00:00
# 61852  NorESM1-ME      rcp45   r1i1p1  2100-12-16 12:00:00
#
#        Sea Surface Height Above Geoid (m)    change
# 0                                0.840088  0.000000
# 1                                0.851699  0.011611
# 2                                0.879345  0.039257
# ...

# %%
df.set_index('date',inplace=True)

# %%
df.to_excel('ZOS_RCP45.xlsx',index=None)

# %%
fig, ax=plt.subplots()
for df1, df_g in df.groupby(['model','projection','ensemble']):
    df_g.sort_index(inplace=True)
    df_seasonal=seasonal_decompose(df_g['change'], model='additive',period=84)
    ax.plot(df_seasonal.trend,label=df1[0]+'_'+df1[1]+'_'+df1[2])
    #ax.plot(df_g.index,df_g['change'],label=df1[0]+'_'+df1[1]+'_'+df1[2])
plt.legend(bbox_to_anchor=(1.22, 1))
#plt.xlim(Data['date'].min(), Data['date'].max())
plt.xlim([datetime(2000, 1, 1), datetime(2105, 12, 31)])
plt.xlabel('Date')
#plt.ylim(0,0.03)
plt.ylabel('relative change')
plt.savefig('zos_rcp45.jpg')

# %%
for df1, df_g in df.groupby(['model','projection','ensemble']):
    if len(df_g)<1139:
        print(df1)
        print(len(df_g))
        print('----------------------------------')
# Out:
# ('CNRM-CM5', 'rcp85', 'r10ip')
# 1019
# ----------------------------------
# ('CNRM-CM5', 'rcp85', 'r1ip')
# 1019
# ----------------------------------
# ('CNRM-CM5', 'rcp85', 'r2i1p1')
# 1019
# ----------------------------------
# ('CNRM-CM5', 'rcp85', 'r4i1p1')
# 1019
# ----------------------------------
# ('CNRM-CM5', 'rcp85', 'r6i1p1')
# 1019
# ----------------------------------
# ('GISS-E2-R', 'rcp85', 'r1i1p2')
# 899
# ----------------------------------
# ('HadGEM2-CC', 'rcp85', 'r2i1p1')
# 1127
# ----------------------------------
# ('HadGEM2-CC', 'rcp85', 'r3i1p1')
# 1127
# ----------------------------------
# ('MIROC5', 'rcp85', 'r4i1p1')
# 359
# ----------------------------------
# ('MIROC5', 'rcp85', 'r5i1p1')
# 359
# ----------------------------------
# ('NorESM1-ME', 'rcp85', 'r1i1p1')
# 467
# ----------------------------------

# %%
fig, ax=plt.subplots()
for df1, df_g in df.groupby(['model','projection','ensemble']):
    df_g.sort_index(inplace=True)
    df_seasonal=seasonal_decompose(df_g['change'], model='additive',period=84)
    ax.plot(df_seasonal.trend,label=df1[0]+'_'+df1[1]+'_'+df1[2])
    #ax.plot(df_g.index,df_g['change'],label=df1[0]+'_'+df1[1]+'_'+df1[2])
plt.legend(bbox_to_anchor=(1.22, 1))
#plt.xlim(Data['date'].min(), Data['date'].max())
plt.xlim([datetime(2000, 1, 1), datetime(2105, 12, 31)])
plt.xlabel('Date')
#plt.ylim(0,0.03)
plt.ylabel('relative change')
plt.savefig('zos_rcp85.jpg')
